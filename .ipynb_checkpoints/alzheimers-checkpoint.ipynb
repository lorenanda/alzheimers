# %% [markdown]
# ### This is a dataset of cross-sectional MRI data in young, middle aged, nondemented and demented older adults, found here https://www.kaggle.com/jboysen/mri-and-alzheimers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cross = pd.read_csv('oasis_cross-sectional.csv', sep=',')
df_cross.head()
# Out:
#               ID M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 0  OAS1_0001_MR1   F    R   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1  OAS1_0002_MR1   F    R   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2  OAS1_0003_MR1   F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3  OAS1_0004_MR1   M    R   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4  OAS1_0005_MR1   M    R   18   NaN  NaN   NaN  NaN  1737  0.848  1.010
#
#    Delay
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df_long = pd.read_csv('oasis_longitudinal.csv', sep=',')
df_long.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# #### We can already see some missing values (NaN), let's find them all and drop them:

# %%
pd.isnull(df_long).sum()
# Out:
# Subject ID     0
# MRI ID         0
# Group          0
# Visit          0
# MR Delay       0
# M/F            0
# Hand           0
# Age            0
# EDUC           0
# SES           19
# MMSE           2
# CDR            0
# eTIV           0
# nWBV           0
# ASF            0
# dtype: int64

# %%
pd.isnull(df_long.dropna(axis=0, how='any')).sum()
# Out:
# Subject ID    0
# MRI ID        0
# Group         0
# Visit         0
# MR Delay      0
# M/F           0
# Hand          0
# Age           0
# EDUC          0
# SES           0
# MMSE          0
# CDR           0
# eTIV          0
# nWBV          0
# ASF           0
# dtype: int64

# %%
df_long.shape
# Out:
# (373, 15)

# %%
df_long.columns
# Out:
# Index(['Subject ID', 'MRI ID', 'Group', 'Visit', 'MR Delay', 'M/F', 'Hand',
#        'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF'],
#       dtype='object')

# %% [markdown]
# #### Rename the column 'M/F' in 'Sex'

# %%
df_long.rename(columns={'M/F': 'Sex'}, inplace=True)
df_long.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay Sex Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# ### Let's see some descriptive stats of this dataset:

# %%
df_long.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  373.000000   373.000000  373.000000  373.000000  354.000000
# mean     1.882038   595.104558   77.013405   14.597855    2.460452
# std      0.922843   635.485118    7.640957    2.876339    1.134005
# min      1.000000     0.000000   60.000000    6.000000    1.000000
# 25%      1.000000     0.000000   71.000000   12.000000    2.000000
# 50%      2.000000   552.000000   77.000000   15.000000    2.000000
# 75%      2.000000   873.000000   82.000000   16.000000    3.000000
# max      5.000000  2639.000000   98.000000   23.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  371.000000  373.000000   373.000000  373.000000  373.000000
# mean    27.342318    0.290885  1488.128686    0.729568    1.195461
# std      3.683244    0.374557   176.139286    0.037135    0.138092
# min      4.000000    0.000000  1106.000000    0.644000    0.876000
# 25%     27.000000    0.000000  1357.000000    0.700000    1.099000
# 50%     29.000000    0.000000  1470.000000    0.729000    1.194000
# 75%     30.000000    0.500000  1597.000000    0.756000    1.293000
# max     30.000000    2.000000  2004.000000    0.837000    1.587000

# %% [markdown]
# #### These are values of all the patients tested, with and without dementia. They tell us something about the experiemntal design and the sample, but not about the differences between the groups of patients with different conditions. So let's analyze the groups separately:

# %%
df_long.Group.describe()
# Out:
# count             373
# unique              3
# top       Nondemented
# freq              190
# Name: Group, dtype: object

# %% [markdown]
# #### There are three group categories of patients, the most common being Nondemented. Let's find the other categories and basic information about the participants in this study:

# %%
df_long.Group.unique()
# Out:
# array(['Nondemented', 'Demented', 'Converted'], dtype=object)

# %% [markdown]
# ### The 'Demented' group:

# %%
demented = df_long[df_long.Group=='Demented']
demented.head()
# Out:
#    Subject ID         MRI ID     Group  Visit  MR Delay Sex Hand  Age  EDUC  \
# 2   OAS2_0002  OAS2_0002_MR1  Demented      1         0   M    R   75    12
# 3   OAS2_0002  OAS2_0002_MR2  Demented      2       560   M    R   76    12
# 4   OAS2_0002  OAS2_0002_MR3  Demented      3      1895   M    R   80    12
# 10  OAS2_0007  OAS2_0007_MR1  Demented      1         0   M    R   71    16
# 11  OAS2_0007  OAS2_0007_MR3  Demented      3       518   M    R   73    16
#
#     SES  MMSE  CDR  eTIV   nWBV    ASF
# 2   NaN  23.0  0.5  1678  0.736  1.046
# 3   NaN  28.0  0.5  1738  0.713  1.010
# 4   NaN  22.0  0.5  1698  0.701  1.034
# 10  NaN  28.0  0.5  1357  0.748  1.293
# 11  NaN  27.0  1.0  1365  0.727  1.286

# %%
demented.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  146.000000   146.000000  146.000000  146.000000  127.000000
# mean     1.732877   452.541096   76.260274   13.671233    2.771654
# std      0.790383   513.838511    6.940193    2.898536    1.196483
# min      1.000000     0.000000   61.000000    6.000000    1.000000
# 25%      1.000000     0.000000   71.000000   12.000000    2.000000
# 50%      2.000000   490.500000   76.000000   13.000000    3.000000
# 75%      2.000000   693.250000   81.000000   16.000000    4.000000
# max      5.000000  2508.000000   98.000000   20.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  144.000000  146.000000   146.000000  146.000000  146.000000
# mean    24.513889    0.671233  1485.849315    0.716301    1.196890
# std      4.497064    0.296173   173.769461    0.031921    0.137177
# min      4.000000    0.500000  1143.000000    0.646000    0.897000
# 25%     22.000000    0.500000  1357.000000    0.694250    1.120000
# 50%     26.000000    0.500000  1476.500000    0.712000    1.188500
# 75%     28.000000    1.000000  1566.500000    0.737000    1.293000
# max     30.000000    2.000000  1957.000000    0.806000    1.535000

# %% [markdown]
# ### The 'Nondemented' group:

# %%
nondemented = df_long[df_long.Group=='Nondemented']
nondemented.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay Sex Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 5  OAS2_0004  OAS2_0004_MR1  Nondemented      1         0   F    R   88    18
# 6  OAS2_0004  OAS2_0004_MR2  Nondemented      2       538   F    R   90    18
# 7  OAS2_0005  OAS2_0005_MR1  Nondemented      1         0   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 5  3.0  28.0  0.0  1215  0.710  1.444
# 6  3.0  27.0  0.0  1200  0.718  1.462
# 7  4.0  28.0  0.0  1689  0.712  1.039

# %%
nondemented.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  190.000000   190.000000  190.000000  190.000000  190.000000
# mean     1.968421   670.242105   77.057895   15.142105    2.394737
# std      0.980796   672.807019    8.096104    2.742149    1.047534
# min      1.000000     0.000000   60.000000    8.000000    1.000000
# 25%      1.000000     0.000000   71.000000   13.000000    2.000000
# 50%      2.000000   631.000000   77.000000   16.000000    2.000000
# 75%      2.750000  1129.750000   82.000000   18.000000    3.000000
# max      5.000000  2517.000000   97.000000   23.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  190.000000  190.000000   190.000000  190.000000  190.000000
# mean    29.226316    0.005263  1495.500000    0.740900    1.191063
# std      0.882722    0.051163   184.888262    0.037705    0.144029
# min     26.000000    0.000000  1106.000000    0.644000    0.876000
# 25%     29.000000    0.000000  1358.250000    0.717250    1.073750
# 50%     29.000000    0.000000  1474.500000    0.739000    1.190000
# 75%     30.000000    0.000000  1634.750000    0.769000    1.292500
# max     30.000000    0.500000  2004.000000    0.837000    1.587000

# %% [markdown]
# ### The 'Converted' group:

# %%
converted = df_long[df_long.Group=='Converted']
converted.head()
# Out:
#    Subject ID         MRI ID      Group  Visit  MR Delay Sex Hand  Age  EDUC  \
# 33  OAS2_0018  OAS2_0018_MR1  Converted      1         0   F    R   87    14
# 34  OAS2_0018  OAS2_0018_MR3  Converted      3       489   F    R   88    14
# 35  OAS2_0018  OAS2_0018_MR4  Converted      4      1933   F    R   92    14
# 36  OAS2_0020  OAS2_0020_MR1  Converted      1         0   M    R   80    20
# 37  OAS2_0020  OAS2_0020_MR2  Converted      2       756   M    R   82    20
#
#     SES  MMSE  CDR  eTIV   nWBV    ASF
# 33  1.0  30.0  0.0  1406  0.715  1.248
# 34  1.0  29.0  0.0  1398  0.713  1.255
# 35  1.0  27.0  0.5  1423  0.696  1.234
# 36  1.0  29.0  0.0  1587  0.693  1.106
# 37  1.0  28.0  0.5  1606  0.677  1.093

# %%
converted.describe()
# Out:
#            Visit     MR Delay        Age       EDUC       SES       MMSE  \
# count  37.000000    37.000000  37.000000  37.000000  37.00000  37.000000
# mean    2.027027   771.810811  79.756757  15.459459   1.72973  28.675676
# std     1.040472   767.296366   7.425203   2.523166   0.96173   1.564432
# min     1.000000     0.000000  65.000000  12.000000   1.00000  24.000000
# 25%     1.000000     0.000000  74.000000  14.000000   1.00000  28.000000
# 50%     2.000000   706.000000  81.000000  16.000000   1.00000  29.000000
# 75%     3.000000  1422.000000  86.000000  18.000000   2.00000  30.000000
# max     5.000000  2639.000000  92.000000  20.000000   4.00000  30.000000
#
#              CDR         eTIV      nWBV        ASF
# count  37.000000    37.000000  37.00000  37.000000
# mean    0.256757  1459.270270   0.72373   1.212405
# std     0.253356   135.432773   0.03543   0.109295
# min     0.000000  1264.000000   0.66600   1.019000
# 25%     0.000000  1383.000000   0.69600   1.106000
# 50%     0.500000  1423.000000   0.71800   1.234000
# 75%     0.500000  1587.000000   0.75000   1.269000
# max     0.500000  1722.000000   0.79900   1.388000

# %% [markdown]
# #### To sum the first observations:
# #### In this sample there are 190 nondemented, 146 demented, and 37 converted patients.
# #### The average age is lowest for the demented patients, namely 76 years, compared to 77 years of nondemented and 79 years for converted patients.
# #### Demented patients have less years of education (on average 13 years) than the other two groups (15 years).
# #### Demented patients have the highest socioeconomic status (2.7) of the two groups (2.3 for nondemented, 1.7 for converted).

# %% [markdown]
# #### Now let's see how the disease factor differ between men and women, across groups.

# %%
def bar_chart(feature):
    Demented = df_long[df_long.Group=='Demented'][feature].value_counts()
    Nondemented = df_long[df_long.Group=='Nondemented'][feature].value_counts()
    Converted = df_long[df_long.Group=='Converted'][feature].value_counts()
    df_bar = pd.DataFrame([Demented,Nondemented,Converted])
    df_bar.index = ['Demented','Nondemented','Converted']
    df_bar.plot(kind='bar',stacked=True, figsize=(9,6))
    
bar_chart('Sex')
plt.xlabel('Group')
plt.ylabel('Number of patients')
plt.legend()
plt.title('Dementia by gender')
# Out:
# Text(0.5,1,'Dementia by gender')

# %% [markdown]
# #### The graph above shows that there are more men with dementia than women.

# %% [markdown]
# ### Estimated intracranial volume (eTIV)

# %%
import seaborn as sns
sns.set(style='whitegrid')
sns.barplot(x='Group', y='eTIV', hue='Sex', data=df_long)

# %% [markdown]
# #### Men also have a higher estimated intracranial volume (eTIV) than women, in all groups. The nondemented patients have the highest eTIV, presumably because the dementia causes the shrinkage of brain tissue.

# %% [markdown]
# ### Normalized whole brain volume (nWBV)

# %%
sns.set(style='whitegrid')
sns.barplot(x='Group', y='nWBV', hue='Sex', data=df_long)

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot('Group', 'nWBV', 'Sex', data=df_long, kind='box')
    g.set_axis_labels('Group', 'nWBV')

# %% [markdown]
# #### Across groups, women have a higher normalized whole brain volume (nWBV) than men. The nondemented patients have the highest nWBV, since the brain is not affected by the disease.

# %%
sns.kdeplot(df_long['nWBV'], shade=True)

# %%
sns.distplot(df_long['nWBV'])
# Out:
# /home/lorena/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
